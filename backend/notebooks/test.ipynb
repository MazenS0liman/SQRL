# %% [markdown]
# # Demo: TabularDataInspectorAgent plan (mocked provider)

# %%
import json
import pandas as pd
from pathlib import Path

# Load a sample dataset from the repo (adjust path if needed)
data_path = Path('..') / 'datasets' / 'AAPL.csv'
df = pd.read_csv(data_path)
print('Loaded rows:', len(df))
print(df.head())
# Out:
# Loaded rows: 10409
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1980-12-12  0.128348  0.128906  0.128348  0.128348   0.100323  469033600
# 1  1980-12-15  0.122210  0.122210  0.121652  0.121652   0.095089  175884800
# 2  1980-12-16  0.113281  0.113281  0.112723  0.112723   0.088110  105728000
# 3  1980-12-17  0.115513  0.116071  0.115513  0.115513   0.090291   86441600
# 4  1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092908   73449600

# %%
from squirrel.modules.agents.inspector.TabularDataInsepctorAgent import TabularDataInspectorAgent

agent = TabularDataInspectorAgent()

# %%
# Example: Make agent generate an EDA plan for the dataset with an optional objective
objective = "Identify trends and anomalies in the stock price data."
plan_json = agent.plan(data=df, objective=objective)
plan = json.loads(plan_json)
plan
# Out:
# 2026-06-02 00:49:23.538 | INFO     | squirrel.modules.agents.abstract.IAgent:get_response:838 - Trying preferred model models/gemini-2.5-flash for provider Provider.GEMINI
# 2026-06-02 00:49:42.170 | INFO     | squirrel.modules.providers.gemini.GeminiProvider:_update_token_usage:301 - Gemini request #1 | Input Tokens: 5906 | Output Tokens: 2780 | Total Tokens: 10019 | Cumulative Total Tokens: 10019
# 2026-06-02 00:49:42.171 | INFO     | squirrel.modules.agents.abstract.IAgent:_call_exact_model:726 - Getting response using provider: Provider.GEMINI, model: models/gemini-2.5-flash, function: generate_json
# Raw response text: {
#   "task": "Identify trends and anomalies in the stock price data.",
#   "dataset": {
#     "rows": 10409,
#     "columns": 7,
#     "column_names": ["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]
#   },
#   "steps": [
#     {
#       "step": 1,
#       "name": "Inspect column types",
#       "inspection": "DataTypeInspectionStrategy",
# ...

# %%
plan
# Out:
# {'task': 'Identify trends and anomalies in the stock price data.',
#  'dataset': {'rows': 10409,
#   'columns': 7,
#   'column_names': ['Date',
#    'Open',
#    'High',
#    'Low',
#    'Close',
#    'Adj Close',
#    'Volume']},
#  'steps': [{'step': 1,
#    'name': 'Inspect column types',
#    'inspection': 'DataTypeInspectionStrategy',
#    'objective': "Identify raw and semantic dtype of each column, especially for the 'Date' column which needs to be parsed.",
#    'actions': ['Classify each column as numeric, categorical, boolean, datetime, or datetime_string.',
#     'Flag low-cardinality numeric columns as likely categorical.',
#     'Flag constant columns and likely identifiers for removal.'],
#    'arguments': {},
#    'expected_output': ['Per-column semantic type',
#     'List of columns requiring attention',
#     'Recommended casting or dropping actions'],
#    'status': 'valid'},
#   {'step': 2,
#    'name': 'Compute summary statistics',
# ...
